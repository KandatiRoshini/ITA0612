# %% [markdown]
# <a href="https://colab.research.google.com/github/KandatiRoshini/ITA0612/blob/main/exp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Electricity Bill Generator

# Input
units = int(input("Enter electricity units consumed: "))

# Bill Calculation
if units <= 100:
    bill = units * 1.5
elif units <= 200:
    bill = (100 * 1.5) + ((units - 100) * 2.5)
elif units <= 300:
    bill = (100 * 1.5) + (100 * 2.5) + ((units - 200) * 4)
else:
    bill = (100 * 1.5) + (100 * 2.5) + (100 * 4) + ((units - 300) * 6)

# Output
print("\n----- Electricity Bill -----")
print("Units Consumed:", units)
print("Total Bill: Rs.", bill)

# %% [markdown]
# ### Debugged Electricity Bill Generator
#
# Below is your code with added `print()` statements for debugging and an example of how to test it with a fixed `units` value.

# %%
print("----- Debugging Electricity Bill Generator -----")

# Input
# Temporarily comment out the input line and set a test value for debugging
# units = int(input("Enter electricity units consumed: "))
units = 250 # Test with 250 units to check the third tier
print(f"DEBUG: Units consumed (for testing): {units}")

# Bill Calculation
bill = 0 # Initialize bill

if units <= 100:
    bill = units * 1.5
    print(f"DEBUG: Units <= 100. Bill: {bill}")
elif units <= 200:
    # Calculate the first 100 units
    first_tier_cost = 100 * 1.5
    # Calculate units in the second tier
    second_tier_units = units - 100
    second_tier_cost = second_tier_units * 2.5
    bill = first_tier_cost + second_tier_cost
    print(f"DEBUG: Units <= 200. First tier cost: {first_tier_cost}, Second tier units: {second_tier_units}, Second tier cost: {second_tier_cost}. Total Bill: {bill}")
elif units <= 300:
    # Calculate the first 100 units
    first_tier_cost = 100 * 1.5
    # Calculate the next 100 units (101-200)
    second_tier_cost = 100 * 2.5
    # Calculate units in the third tier
    third_tier_units = units - 200
    third_tier_cost = third_tier_units * 4
    bill = first_tier_cost + second_tier_cost + third_tier_cost
    print(f"DEBUG: Units <= 300. First tier cost: {first_tier_cost}, Second tier cost: {second_tier_cost}, Third tier units: {third_tier_units}, Third tier cost: {third_tier_cost}. Total Bill: {bill}")
else:
    # Calculate the first 100 units
    first_tier_cost = 100 * 1.5
    # Calculate the next 100 units (101-200)
    second_tier_cost = 100 * 2.5
    # Calculate the next 100 units (201-300)
    third_tier_cost = 100 * 4
    # Calculate units in the fourth tier
    fourth_tier_units = units - 300
    fourth_tier_cost = fourth_tier_units * 6
    bill = first_tier_cost + second_tier_cost + third_tier_cost + fourth_tier_cost
    print(f"DEBUG: Units > 300. First tier cost: {first_tier_cost}, Second tier cost: {second_tier_cost}, Third tier cost: {third_tier_cost}, Fourth tier units: {fourth_tier_units}, Fourth tier cost: {fourth_tier_cost}. Total Bill: {bill}")

# Output
print("\n----- Electricity Bill -----")
print("Units Consumed:", units)
print("Total Bill: Rs.", bill)
print("------------------------------")

# %% [markdown]
# ### Debugging Tips for the Electricity Bill Calculator
#
# 1.  **Use `print()` statements**: Insert `print()` statements at various points in your code to inspect the values of variables. For example, you could print the `units` value after input, and the `bill` value within each `if/elif/else` block.
#
#     ```python
#     # Example of adding print statements
#     units = int(input("Enter electricity units consumed: "))
#     print(f"DEBUG: Units entered: {units}") # Added debug print
#
#     if units <= 100:
#         bill = units * 1.5
#         print(f"DEBUG: Bill calculated for <=100 units: {bill}") # Added debug print
#     # ... (add similar prints to other blocks)
#     ```
#
# 2.  **Test with specific values**: Since `input()` might not be interactive in all Colab execution contexts, you can temporarily comment out the `input()` line and assign a specific value to `units` to test different scenarios.
#
#     ```python
#     # units = int(input("Enter electricity units consumed: "))
#     units = 150 # Test with a value that falls into the second tier
#
#     # ... rest of your bill calculation code
#     ```
#
# 3.  **Break down the logic**: If the calculations are complex, break them down into smaller, verifiable steps. For example, print the intermediate values after each tier's calculation to ensure they are correct before adding them up.
#
# 4.  **Consider using a debugger (for more complex issues)**: For very complex problems, you could explore Python's built-in `pdb` (Python Debugger) or tools like `ipdb` which offer more interactive debugging. However, for this type of script, `print()` statements are usually sufficient.
